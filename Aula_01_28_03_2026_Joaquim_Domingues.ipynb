# %% [markdown]
# 1. Estrutura Básica de um Programa em Python
# Um programa em Python é composto por instruções executadas sequencialmente, de cima para baixo. Diferente de outras linguagens, Python não exige um método principal ( main) ou estrutura complexa para iniciar a execução.
#
# Exemplo simples:

# %%
print("Meu primeiro programa em Python")
# Out:
# Meu primeiro programa em Python

# %% [markdown]
# 2. Comentários em Python
# Os comentários são usados ​​para explicar o código e não são executados pelo interpretador.
#
# 2.1 Comentário de uma linha

# %%
# Este é um comentário
print("Olá, Python")
# Out:
# Olá, Python

# %% [markdown]
# 2.2 Comentário de múltiplas linhas (docstring)

# %%
"""
Este programa imprime uma mensagem na tela.
Utilizado apenas como exemplo.
"""
print("Exemplo com docstring")
# Out:
# Exemplo com docstring

# %% [markdown]
# 3. Variáveis
# Variáveis ​​são utilizadas para armazenar valores na memória.
#
# Características das variáveis ​​em Python
# Não é necessário declarar o tipo
# O tipo é inferido automaticamente
# O valor pode ser alterado durante a execução
# Exemplo:

# %%
nome = "Ana"
idade = 20
altura = 1.65

# %% [markdown]
# 4. Tipos de Dados Básicos
# 4.1 Inteiro (int)

# %%
quantidade = 10

# %% [markdown]
# 4.2 Ponto flutuante (flutuar)

# %%
preco = 19.90

# %% [markdown]
# 4.3 Texto (str)

# %%
mensagem = "Python é incrível"

# %% [markdown]
# 4.4 Booleano (bool)

# %%
aprovado = True

# %% [markdown]
# 5. Tipo de função()
# A função type()permite verificar o tipo de dado.

# %%
print(type(idade))
print(type(preco))
print(type(mensagem))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 6. Entrada de Dados com input()
# A função input()permite receber dados digitalizados pelo usuário.

# %%
nome = input("Digite seu nome: ")
print("Bem-vindo,", nome)
# Out:
# Digite seu nome: j
# Bem-vindo, j

# %% [markdown]
# Observação: Todo valor recebido via input()é do tipo string.
#
# 7. Conversão de Tipos (Casting)
# Para converter valores entre tipos, utilizamos funções específicas.

# %%
idade = int(input("Digite sua idade: "))
altura = float(input("Digite sua altura: "))
# Out:
# Digite sua idade: 4
# Digite sua altura: 52

# %% [markdown]
# 8. Operadores Aritméticos
# Operador	Descrição
# +	Adição
# -	Subentende
# *	Multiplicação
# /	Divisão
# //	Divisão inteira
# %	Restaurante
# **	Potência

# %%
a = 10
b = 3

print(a + b)
print(a * b)
print(a ** b)
# Out:
# 13
# 30
# 1000

# %% [markdown]
# 9. Boas Práticas Iniciais
# Utilize nomes de variáveis ​​claros e descritivos
# Evite acentuação e espaços em nomes
# Use letras minúsculas e _(snake_case)
# Exemplo:

# %%
media_final = 7.5
total_alunos = 30

# %% [markdown]
# 10. Exercícios Propostos
# Crie um programa que solicite o nome e a idade do usuário e exiba uma mensagem personalizada.
# Leia dois números digitados pelo usuário e exiba a soma.
# Calcule a média de três notas informadas pelo usuário.

# %% [markdown]
# 1- Solicite o nome e a idade do usuário e exiba uma mensagem personalizada

# %%
"""
Este programa imprime uma mensagem na tela.
Utilizado apenas como exemplo.
"""
print("Seu aniversário chegou parabens, para ganhar nosso vale presente digite seu nome e sua idade. ")
# Out:
# Seu aniversário chegou parabens, para ganhar nosso vale presente digite seu nome e sua idade.

# %%
nome = print("Digite seu nome")
# Out:
# Digite seu nome

# %%
Idade = print("Digite a sua idade")
# Out:
# Digite a sua idade

# %% [markdown]
# 2 - Leia dois números digitados pelo usuário e exiba a soma

# %%
a = 10
b = 12

print(a+b)
# Out:
# 22

# %% [markdown]
# 3 - Calcule a média de três notas informadas pelo usuário.

# %%
c = 8
d = 9
e = 10

total_de_alunos = 3

print("Média",((c+d+e)/total_de_alunos))
# Out:
# Média 9.0
